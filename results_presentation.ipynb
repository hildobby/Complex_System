# %%
# import the local python files
from src.lattice import *
from src.main import *

# %matplotlib notebook

# %% [markdown]
# # Expanding on the Bak-Snappen model
#
#  By Hildebert Moulié, Philippe Nicolau, Louis Weyland & Binjie Zhou
#
# <figure class="half" style="display:flex">
#     <img style="width:300px" src="images/uva_logo.png">
#     <img style="width:300px" src="images/vu_logo.png">
# </figure>

# %% [markdown]
# # Presentation overview
#
# 1. The Bak-Snappen Model
# 2. Introduction
# 3. Hypothesis
# 4. Formulas Behind the model
# 5. Results
#     * Average fitness
#     * Avalanche time
#     * Mutation Distance
# 6. Conclusion
# 7. Further Research
# 8. References

# %% [markdown]
# # The Bak-Sneppen Model
#
# A model representing the co-evolution of species. It highlights the self organising behaviour of species based on different factors. It is usually created as a single dimensional lattice model. Following its creation for co-evolution, it was also shown that it could be used for many other purposes including segregation.

# %% [markdown]
# # Introduction
#
# After having observed the Bak-Snappen model, we believed it to be very limited in its use. In order for it to be a better representation of reality, two-dimensional and three dimensional versions of the model were coded using Python 3.8 with the _Networkx_ package.

# %% [markdown]
# # Formulas behind the model

# %% [markdown]
# # The Results

# %% [markdown]
# # Average fitness

# %%
comp_average_fitness(size=(20,20), iteration=2000, repetition=10, std=0.3)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Avalanche time

# %%
comp_avalanche_time(size=(20,20), iteration=2000, repetition=10, std=0.2)
# Out:
# The slope with a uniform distribution is 5.848664115786331
# If -0.6877275704373415 > 0, the distribution of the data with uniform distribution resembles more a powerlaw than exponential distribution
# with a p value of 0.4916243546452216
# The slope with a Gaussian distribtion is 3.0375737343025873
# If -2.0300059849623007 > 0, the distribution of the data with a gaussian distribution resembles more a powerlaw than exponential distribution
# with a p value of 0.04235593093077129
# Calculating best minimal value for power law fit
# Calculating best minimal value for power law fit
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Mutation distance

# %%
comp_mutation_dist(size=(20,20), iteration=2000, repetition=10, std=0.2)
# Out:
# The slope with a uniform distribution is 7.84604441998993
# If -2.6325134842897886 > 0, the distribution of the data with uniform distribution resembles more a powerlaw than exponential distribution
# with a p value of 0.008475565852999281
# The slope with a Gaussian distribtion is 10.053214080373303
# If -2.5695483449495247 > 0, the distribution of the data with a gaussian distribution resembles more a powerlaw than exponential distribution
# with a p value of 0.010183118206417771
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# Values less than or equal to 0 in data. Throwing out 0 or negative values
# Calculating best minimal value for power law fit
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Avalanche distribution

# %%
comp_diff_neighbours(size=(20, 20),iteration = 2000,repetition = 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-93da30d8a19f> in <module>
# ----> 1 comp_diff_neighbours(size=(20, 20),iteration = 2000,repetition = 10)
#
# ~/gits/Complex_System/src/main.py in comp_diff_neighbours(size, iteration, repetition)
#     213                           iterations=iterations,neighbourhood='vonNeumann')
#     214
# --> 215         moore.run(["mutation","avalanche_time","get_dist_btw_mutation"])
#     216         vonNeumann.run(["mutation","avalanche_time","get_dist_btw_mutation"])
#     217
#
# ~/gits/Complex_System/src/lattice.py in run(self, things_to_collect)
#     353
#     354             # get the neighbours
# --> 355             self.neighbours_list = self.get_neighbours(self.min_pos)
#     356
#     357             # assign new random number to the lowest fitness and its neighbours
#
# ~/gits/Complex_System/src/lattice.py in get_neighbours(self, chosen_node)
#     184             return neighbours_list
#     185
# --> 186         elif self.neighbourdhood == 'Moore':
#     187             neighbours_list = list()
#     188             # Calculate the neighbours for this object
#
# AttributeError: 'Lattice' object has no attribute 'neighbourdhood'

# %% [markdown]
# # Conclusion

# %% [markdown]
# # Further Research

# %% [markdown]
# # References
#
# * Bak, P., & Sneppen, K. (1993). Punctuated equilibrium and criticality in a simple model of evolution. Physical review letters, 71(24), 4083.
# * Fraiman, D. (2018). Bak-Sneppen model: Local equilibrium and critical value. Physical Review E, 97(4), 042123.
# * Paczuski, M., Maslov, S., & Bak, P. (1996). Avalanche dynamics in evolution, growth, and depinning models. Physical Review E, 53(1), 414.
